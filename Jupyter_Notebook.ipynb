# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
#
# ##Tools for Data Science - Final Exam

# %% [markdown]
# Exercise 3 - Create a markdown cell for an introduction. (1 pt)
#
# Introduction

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
#
# ##List of Data Science languages:
#
# #Popular languages: Python, R, SQL, Scala, Java, C++
#
# #Other languages: Javascript, PHP, Go, Ruby, Visual Basic

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
#
# Scientific computing librairies: Pandas, Numpy
# Visualization librairies: Matplotlib, Seaborn
# Machine Learning & Deep Learning: Scikit-learn, Keras
# Deep Learning: TensorFlow, PyTorch

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
#
# | Category | Open Source Tools |
# |---|---|
# | Data Management Tools | mySQL, PostgreSQL... |
# | Data integration & transformation tools | Apache AirFlor, KubeFlow, Kafka... |
# | Data Visualization tools | Pixie Dust, Hue, Kibana... |
# | Model Deployment tools | Apache Prediction IO, Seldon, Kubernetes... |
# | Model Moniroring tools | ModelDB, Prometheus, IBM Fairness 360... |
# | Code asset management tools | Git, Github, gitlab... |

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
#
# Operator	Example
# '+	        x + y
# '-	        x - y
# '*	        x * y
# /	        x / y

# %%
#Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)

number_1 = 5
number_2 = 3

multiply = number_1 * number_2
add = number_1 + number_2

print(multiply)
print(add)
# Out:
# 15
# 8

# %%
#Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

duration_min = 352
min_to_hour = 60

time = duration_min / min_to_hour

print(str(time) + " hour")
# Out:
# 5.866666666666666 hour

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
#
# Objective 1
#
# Objective 2
#
# Objective 3
#
# Objective 4
#
# Objective 5

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
#
# Name = Guillaume Pien

# %% [markdown]
# Exercise 12 - Share your notebook through GitHub (3 pts)
#
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)
